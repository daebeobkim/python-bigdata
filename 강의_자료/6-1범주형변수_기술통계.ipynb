# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("mpg")
df.shape
# Out:
# (398, 9)

# %%
df.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       93
# weight          351
# acceleration     95
# model_year       13
# origin            3
# name            305
# dtype: int64

# %%
sns.countplot(data=df,y="origin") #countplot으로 빈도수 시각화
# Out:
# <AxesSubplot:xlabel='count', ylabel='origin'>

# %%
df["origin"].value_counts() #origin빈도수 구하기
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
sns.countplot(data=df,x="origin",hue="cylinders") #cylinder로 색상 표현
# Out:
# <AxesSubplot:xlabel='origin', ylabel='count'>

# %%
sns.countplot(data=df,x="cylinders",hue = "origin")  #origin으로 색상 표현
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='count'>

# %%
pd.crosstab(df["origin"],df["cylinders"]) #시각화한 값 직접 구하기
# Out:
# cylinders  3   4  5   6    8
# origin
# europe     0  63  3   4    0
# japan      4  69  0   6    0
# usa        0  72  0  74  103
