# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold

(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()
x_train=x_train.reshape(60000,28,28,1)
x_test=x_test.reshape(10000,28,28,1)
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)




cnn=Sequential()
cnn.add(Conv2D(16,(5,5),padding='same',activation='relu',input_shape=(28,28,1)))
cnn.add(Conv2D(16,(5,5),padding='same',activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Conv2D(32,(5,5),padding='same',activation='relu'))
cnn.add(Conv2D(32,(5,5),padding='same',activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Flatten())
cnn.add(Dense(84,activation='relu'))
cnn.add(Dense(10,activation='softmax'))

cnn_drop=Sequential()
cnn_drop.add(Conv2D(16,(5,5),padding='same',activation='relu',input_shape=(28,28,1)))
cnn_drop.add(Conv2D(16,(5,5),padding='same',activation='relu'))
cnn_drop.add(MaxPooling2D(pool_size=(2,2)))
cnn_drop.add(Dropout(0.50))
cnn_drop.add(Conv2D(32,(5,5),padding='same',activation='relu'))
cnn_drop.add(Conv2D(32,(5,5),padding='same',activation='relu'))
cnn_drop.add(MaxPooling2D(pool_size=(2,2)))
cnn_drop.add(Dropout(0.50))
cnn_drop.add(Flatten())
cnn_drop.add(Dense(84,activation='relu'))
cnn_drop.add(Dropout(0.50))
cnn_drop.add(Dense(10,activation='softmax'))


cnn.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
hist=cnn.fit(x_train,y_train,batch_size=128,epochs=30,validation_data=(x_test,y_test),verbose=2)

cnn_drop.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
hist2=cnn_drop.fit(x_train,y_train,batch_size=128,epochs=30,validation_data=(x_test,y_test),verbose=2)

res=cnn.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)

res2=cnn_drop.evaluate(x_test,y_test,verbose=0)
print("정확률은",res2[1]*100)

import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title("model accuracy")
plt.ylabel('accuracy')
plt.xlabel('ephoch')
plt.legend(['Train','Validation'], loc='best')
plt.grid()
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model loss")
plt.ylabel('loss')
plt.xlabel('ephoch')
plt.legend(['Train','Validation'], loc='best')
plt.grid()
plt.show()

plt.plot(hist2.history['accuracy'])
plt.plot(hist2.history['val_accuracy'])
plt.title("model2 accuracy")
plt.ylabel('accuracy')
plt.xlabel('ephoch')
plt.legend(['Train','Validation'], loc='best')
plt.grid()
plt.show()

plt.plot(hist2.history['loss'])
plt.plot(hist2.history['val_loss'])
plt.title("model2 loss")
plt.ylabel('loss')
plt.xlabel('ephoch')
plt.legend(['Train','Validation'], loc='best')
plt.grid()
plt.show()
# Out:
# Epoch 1/30
# 469/469 - 59s - loss: 0.5046 - accuracy: 0.8164 - val_loss: 0.3544 - val_accuracy: 0.8709 - 59s/epoch - 126ms/step
# Epoch 2/30
# 469/469 - 56s - loss: 0.3037 - accuracy: 0.8897 - val_loss: 0.2955 - val_accuracy: 0.8906 - 56s/epoch - 120ms/step
# Epoch 3/30
# 469/469 - 61s - loss: 0.2567 - accuracy: 0.9061 - val_loss: 0.2612 - val_accuracy: 0.9053 - 61s/epoch - 130ms/step
# Epoch 4/30
# 469/469 - 77s - loss: 0.2281 - accuracy: 0.9171 - val_loss: 0.2669 - val_accuracy: 0.8977 - 77s/epoch - 164ms/step
# Epoch 5/30
# 469/469 - 79s - loss: 0.2011 - accuracy: 0.9273 - val_loss: 0.2403 - val_accuracy: 0.9138 - 79s/epoch - 168ms/step
# Epoch 6/30
# 469/469 - 71s - loss: 0.1834 - accuracy: 0.9319 - val_loss: 0.2485 - val_accuracy: 0.9123 - 71s/epoch - 151ms/step
# Epoch 7/30
# 469/469 - 76s - loss: 0.1659 - accuracy: 0.9386 - val_loss: 0.2239 - val_accuracy: 0.9180 - 76s/epoch - 161ms/step
# Epoch 8/30
# ...
