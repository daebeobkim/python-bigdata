# %%
import requests
from bs4 import BeautifulSoup
url = 'https://news.sbs.co.kr/news/endPage.do?news_id=N1007428292&plink=STAND&cooper=NAVERMAIN'
requests.get(url)
# Out:
# <Response [200]>

# %%
a = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
a.content.decode()
# Out:
# '<!doctype html>\r\n<html lang="ko" itemscope itemtype="http://schema.org/NewsArticle"  xmlns:og="http://opengraphprotocol.org/schema/">\r\n<head>\r\n<meta charset="utf-8">\r\n<meta name=attribution content="SBS">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<title>인증 오류로 온오프 &#39;민원 대란&#39;&hellip;&#34;해법 몰라 복구 못해&#34;</title>\r\n<meta name="title" content="인증 오류로 온오프 &#39;민원 대란&#39;&hellip;&#34;해법 몰라 복구 못해&#34;">\r\n<meta name="viewport" content="width=970">\r\n<link rel="shortcut icon" href="https://news.sbs.co.kr/favicon.ico" type="image/x-icon">\r\n<link rel="icon" href="https://news.sbs.co.kr/favicon_32x32.png" sizes="32x32"><link rel="icon" href="https://news.sbs.co.kr/favicon_48x48.png" sizes="48x48"><link rel="icon" href="https://news.sbs.co.kr/favicon_96x96.png" sizes="96x96"><link rel="icon" href="https://news.sbs.co.kr/favicon_144x144.png" sizes="144x144">\t\r\n<link rel="canonical" href="https://news.sbs.co.kr/news/endPage.do?news_id=N1007428292">\r\n\r\n<
# ...

# %%
bs = BeautifulSoup(a.text)
bs.select_one('#news-title').string
# Out:
# '인증 오류로 온오프 \'민원 대란\'…"해법 몰라 복구 못해"'
