# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt


data = pd.read_csv("C:/Users/rlaeo/OneDrive/바탕 화면/gpascore.csv")
data.isnull().sum()
data = data.dropna()
y = data['admit'].values
x = []
for i,rows in data.iterrows():
    x.append([rows['gre'],rows['gpa'],rows['rank']])

model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64,activation='tanh'),
    tf.keras.layers.Dense(64,activation='tanh'),
    tf.keras.layers.Dense(64,activation='tanh'),
    tf.keras.layers.Dense(1,activation='sigmoid'),
])
model.compile(optimizer='adam' ,loss= 'binary_crossentropy',metrics=['accuracy'])
model.fit(np.array(x),np.array(y),epochs=1000)

예측 = model.predict([[750,3.70,3],[400,2.2,1]])
예측
# Out:
# Epoch 1/1000
# 14/14 [==============================] - 1s 2ms/step - loss: 0.7029 - accuracy: 0.5388
# Epoch 2/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6993 - accuracy: 0.5082
# Epoch 3/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6781 - accuracy: 0.5576
# Epoch 4/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6645 - accuracy: 0.6118
# Epoch 5/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6578 - accuracy: 0.6024
# Epoch 6/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6736 - accuracy: 0.5553
# Epoch 7/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6815 - accuracy: 0.5553
# Epoch 8/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6742 - accuracy: 0.5388
# Epoch 9/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6569 - accuracy: 0.5953
# Epoch 10/1000
# ...

# %%
history = model.fit(np.array(x), np.array(y), epochs=1000)

# 손실 그래프
plt.plot(history.history['loss'])
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# 정확도 그래프
plt.plot(history.history['accuracy'])
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Epoch 1/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5731 - accuracy: 0.7059
# Epoch 2/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5635 - accuracy: 0.7059
# Epoch 3/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5541 - accuracy: 0.7271
# Epoch 4/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5386 - accuracy: 0.7176
# Epoch 5/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4914 - accuracy: 0.7835
# Epoch 6/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4973 - accuracy: 0.7812
# Epoch 7/1000
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4943 - accuracy: 0.7859
# Epoch 8/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5100 - accuracy: 0.7671
# Epoch 9/1000
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5132 - accuracy: 0.7600
# Epoch 10/1000
# ...
